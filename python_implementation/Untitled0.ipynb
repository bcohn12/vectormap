# %%
from scipy.io import loadmat
from numpy.linalg import pinv
from numpy import matrix, diag
mat_data_struct = loadmat('../output/C_13_14_16_18_19_20_21_23_25_30_27_5.mat')

# %%
mat_data_struct['C'][1]
# Out:
# array([ array([[  1.65132912e-01,   5.71099399e-03,  -9.86254787e-01, ...,
#          -1.00000000e+00,   1.87894298e-01,  -1.00000000e+00],
#        [  2.35155018e-01,   2.24612363e-02,  -9.71698313e-01, ...,
#          -1.00000000e+00,   1.96710942e-01,  -1.00000000e+00],
#        [  3.35811200e-01,   2.87231876e-02,  -9.41491273e-01, ...,
#          -1.00000000e+00,   2.11658802e-01,  -1.00000000e+00],
#        ...,
#        [  2.83900115e-01,  -3.77829027e-03,   9.58846416e-01, ...,
#          -1.00000000e+00,   7.81042808e-12,  -1.00000000e+00],
#        [  3.40726232e-01,   3.87025991e-02,   9.39365607e-01, ...,
#          -1.00000000e+00,   1.06794401e-11,  -1.00000000e+00],
#        [  1.79584292e-01,   2.83867440e-03,   9.83738494e-01, ...,
#          -1.00000000e+00,   5.83771549e-13,  -1.00000000e+00]]),
#        array([[  1.65132912e-01,   5.71099399e-03,  -9.86254787e-01, ...,
#          -1.00000000e+00,   2.28806017e-01,  -1.00000000e+00],
# ...
